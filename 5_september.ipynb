# %% [markdown]
# <a href="https://colab.research.google.com/github/yash361-code/reinforcement_learning01/blob/main/5_september.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)

# %%
x = np.random.randint(0,900,1000)

# %%
x
# Out:
# array([ 37, 235,  72, 767, 715, 645, 847, 144, 129, 583, 749, 508, 390,
#        281, 178, 276, 254, 357, 468, 252, 490, 668, 398, 562, 580, 215,
#        753, 503, 478, 864,  86, 141, 393,   7, 319, 829, 534, 313, 513,
#        896, 316, 209, 264, 728, 653, 627, 431, 633, 456, 542,  71, 387,
#        454, 561, 313, 515, 792, 497,  43, 588,  26, 820, 336, 621, 883,
#        297, 466,  15,  64, 196,  25, 367, 738, 471, 282, 665, 616,  22,
#        777, 707, 126, 279, 381, 356, 155, 313, 595, 166, 648, 288, 418,
#        778, 279, 655, 751,  87, 793, 243, 348, 586, 190, 302, 728, 151,
#        695, 321, 369, 845, 771, 896, 253, 461, 774, 564, 469, 454, 514,
#        588, 149, 715, 263,  77, 712,  75, 332,  43, 532, 542, 548, 871,
#        775, 813, 569, 752, 508, 210,  96, 269,  10, 279, 892, 849, 889,
#        152, 714, 476, 660, 416, 140, 193, 606, 572, 489, 152, 338, 883,
#        865, 130, 492, 732, 615, 866, 266, 694, 864, 489, 850, 470, 198,
# ...

# %%
y =x+np.random.normal(0,100,1000)

# %%
y
# Out:
# array([ 6.45214078e+01,  2.02318217e+02,  4.17469518e+01,  6.94289965e+02,
#         9.15654770e+02,  7.50352638e+02,  9.81443193e+02,  1.25994734e+02,
#         8.20251747e+01,  4.29889407e+02,  7.70554468e+02,  6.44884290e+02,
#         3.08003630e+02,  1.98036848e+02,  3.45675900e+01,  3.45746131e+02,
#         2.13217208e+01,  4.04170973e+02,  5.09100664e+02,  2.47684161e+02,
#         5.07231688e+02,  5.35544332e+02,  3.92744686e+02,  3.84551015e+02,
#         5.01007800e+02,  2.73620106e+02,  7.76056383e+02,  5.63599644e+02,
#         3.88166181e+02,  9.15444689e+02,  1.75081442e+02,  3.03539181e+02,
#         4.17489301e+02,  2.21472722e+02,  3.14336234e+02,  7.52256821e+02,
#         7.71724555e+02,  2.82238128e+02,  4.94981718e+02,  8.33281145e+02,
#         2.68165036e+02,  3.49531009e+02,  2.69536803e+02,  8.01698251e+02,
#         4.59750078e+02,  5.66501397e+02,  3.91498370e+02,  6.19388534e+02,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.       , 0.9300571],
#        [0.9300571, 1.       ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
x= np.random.randint(0,50,1000)
y=np.random.randint(0,50,1000)
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.01755254],
#        [0.01755254, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd
df =pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,10,1000)
df['c']=100-df['a']+np.random.normal(0,5,1000)
df['d']=np.random.randint(0,50,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.819009 -0.943399  0.018120
# b  0.819009  1.000000 -0.775961  0.029897
# c -0.943399 -0.775961  1.000000 -0.016393
# d  0.018120  0.029897 -0.016393  1.000000

# %%
import pandas as pd
df =pd.DataFrame({'a':np.random.randint(0,100,1000)})
df['b']=df['a']+np.random.normal(0,150,1000)
df['c']=100-df['a']+np.random.normal(0,50,1000)
df['d']=np.random.randint(0,500,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.136721 -0.508789  0.054702
# b  0.136721  1.000000 -0.040642  0.038999
# c -0.508789 -0.040642  1.000000  0.002093
# d  0.054702  0.038999  0.002093  1.000000

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
